# %%
import pandas as pd
import joblib

model = joblib.load('../models/gbr.pkl')

# test = pd.read_csv('../data/raw/test.csv')
# test_processed = test[selected_features]  # same features as training
# test_processed = test_processed.fillna(0)

# preds = model.predict(test_processed)

# submission = pd.DataFrame({'Id': test['Id'], 'SalePrice': preds})
# submission.to_csv('../data/submissions/submission_01.csv', index=False)
